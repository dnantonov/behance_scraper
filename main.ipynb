# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.behance.net',
    'accept': '*/*',
    'x-bcp': '0e94cad1-98bc-4948-9193-434abe97f815',
    'x-requested-with': 'XMLHttpRequest',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36',
    'sec-gpc': '1',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': 'gk_suid=29269953; gki=%7B%22feature_stock_rail%22%3Afalse%7D; bcp=0e94cad1-98bc-4948-9193-434abe97f815; AMCVS_9E1005A551ED61CA0A490D45%40AdobeOrg=1; gpv=behance.net:search:projects; s_cc=true; OptanonConsent=isIABGlobal=false&datestamp=Fri+Jan+21+2022+18%3A50%3A24+GMT%2B0300+(%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D0%B0%2C+%D1%81%D1%82%D0%B0%D0%BD%D0%B4%D0%B0%D1%80%D1%82%D0%BD%D0%BE%D0%B5+%D0%B2%D1%80%D0%B5%D0%BC%D1%8F)&version=6.9.0&hosts=&consentId=d0a29a75-eba3-4af9-93aa-6089e0c21cec&interactionCount=0&landingPath=https%3A%2F%2Fwww.behance.net%2F&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1; feds_privacy_consent={"hasUserProvidedConsent":true,"userHasCustomConsent":false}; s_sq=%5B%5BB%5D%5D; sign_up_prompt=true; AMCV_9E1005A551ED61CA0A490D45%40AdobeOrg=870038026%7CMCMID%7C56586488518047349773733653051510070332%7CMCAID%7CNONE%7CMCOPTOUT-1642787470s%7CNONE%7CvVersion%7C5.0.0',
}

params = (
    ('content', 'projects'),
    ('field', 'architecture'),
    ('ordinal', '0'),
)

response = requests.get('https://www.behance.net/search', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['search', 'creativeFields', 'tools', 'schools'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
# result items (total: 48)
result_items = results_json['search']['content']['projects']

# %%
# check the length
len(result_items)
# Out:
# 48

# %%
result_items[0]
# Out:
# {'id': 106428599,
#  'name': 'CCBD\xa0Exhibition Pavilion | CCBD 展示中心',
#  'published_on': 1603903775,
#  'created_on': 1603256704,
#  'modified_on': 1642856422,
#  'url': 'https://www.behance.net/gallery/106428599/CCBDExhibition-Pavilion-CCBD-',
#  'slug': 'CCBDExhibition-Pavilion-CCBD-',
#  'privacy': 'public',
#  'fields': ['Architecture', 'Photography', 'Architecture Photography'],
#  'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/25688c106428599.Y3JvcCwxMTQyLDg5NCwzNjIsMA.jpg',
#   '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/25688c106428599.Y3JvcCwxMTQyLDg5NCwzNjIsMA.jpg',
#   '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/25688c106428599.Y3JvcCwxMTQyLDg5NCwzNjIsMA.jpg',
#   '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/25688c106428599.Y3JvcCwxMTQyLDg5NCwzNjIsMA.jpg',
#   '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/25688c106428599.Y3JvcCwxMTQyLDg5NCwzNjIsMA.jpg',
#   'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/25688c106428599.Y3JvcCwxMTQyLDg5NCwzNjIsMA.jpg',
#   'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/25688c106428599.Y3JvcCwxMTQyLDg5NCwzNjIsMA.jpg'},
#  'mature_content': 0,
#  'mature_access': 'allowed',
#  'owners': [{'id': 42219655,
#    'first_name': 'Xiao',
#    'last_name': 'Tan-谭啸',
#    'username': 'tan-xiao',
#    'city': "Xi'an",
#    'state': '',
#    'country': 'China',
#    'location': "Xi'an, China",
#    'company': 'Studio Ten',
#    'occupation': 'Interior & Architectural Photographer',
#    'created_on': 1470615379,
#    'url': 'https://www.behance.net/tan-xiao',
#    'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/675f7542219655.5eafba2f34a00.jpg',
#     '100': 'https://mir-s3-cdn-cf.behance.net/user/100/675f7542219655.5eafba2f34a00.jpg',
#     '115': 'https://mir-s3-cdn-cf.behance.net/user/115/675f7542219655.5eafba2f34a00.jpg',
#     '230': 'https://mir-s3-cdn-cf.behance.net/user/230/675f7542219655.5eafba2f34a00.jpg',
#     '138': 'https://mir-s3-cdn-cf.behance.net/user/138/675f7542219655.5eafba2f34a00.jpg',
#     '276': 'https://mir-s3-cdn-cf.behance.net/user/276/675f7542219655.5eafba2f34a00.jpg'},
#    'display_name': 'Xiao Tan-谭啸',
#    'fields': ['Photography', 'Interior Design', 'Architecture'],
#    'has_default_image': 0,
#    'website': 'www.xiaotan-studioten.com',
#    'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/1b723953b5c4b8f04ce429a73fea9a06/5ccd5f26-6fa8-4afa-8d96-b06a7e28e204_rwc_308x0x2584x410x3200.jpg?h=9a41f79d882b20d19826748532c1d0f7',
#    'has_premium_access': False,
#    'stats': {'followers': 17314,
#     'following': 474,
#     'comments': 19,
#     'appreciations': 41925,
#     'views': 608844}},
#   {'id': 472127935,
#    'first_name': 'SANGU',
#    'last_name': 'design',
#    'username': 'Sangu-Design',
#    'city': 'Guangzhou',
#    'state': '',
#    'country': 'China',
#    'location': 'Guangzhou, China',
#    'company': 'SANGU design',
#    'occupation': '',
#    'created_on': 1578294077,
#    'url': 'https://www.behance.net/Sangu-Design',
#    'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/eb0276472127935.5e12e12aba00a.jpg',
#     '100': 'https://mir-s3-cdn-cf.behance.net/user/100/eb0276472127935.5e12e12aba00a.jpg',
#     '115': 'https://mir-s3-cdn-cf.behance.net/user/115/eb0276472127935.5e12e12aba00a.jpg',
#     '230': 'https://mir-s3-cdn-cf.behance.net/user/230/eb0276472127935.5e12e12aba00a.jpg',
#     '138': 'https://mir-s3-cdn-cf.behance.net/user/138/eb0276472127935.5e12e12aba00a.jpg',
#     '276': 'https://mir-s3-cdn-cf.behance.net/user/276/eb0276472127935.5e12e12aba00a.jpg'},
#    'display_name': 'SANGU design',
#    'fields': ['Photography', 'Interior Design', 'Architecture'],
#    'has_default_image': 0,
#    'website': 'http://www.guuuuuu.com/',
#    'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/3af2e918c43e48969c287d8b52955337/3b4e4310-b71d-4978-9246-e7a3c2279d6e_rwc_0x1215x9073x1001x9073.jpg?h=60abae5b0f466188f229a1af17841d3c',
#    'has_premium_access': False,
#    'stats': {'followers': 2652,
#     'following': 1,
#     'comments': 0,
#     'appreciations': 5036,
#     'views': 63622}}],
#  'stats': {'views': 8343, 'appreciations': 677, 'comments': 29},
#  'conceived_on': 1603238400,
#  'premium': 0,
#  'linked_asset_count': 0,
#  'linked_assets': [],
#  'features': [{'featured_on': 1604350826,
#    'site': {'id': 133,
#     'parent_id': 5,
#     'name': 'Архитектурная фотография',
#     'key': 'ArPh',
#     'icon': 'https://a5.behance.net/e14d6c7ba08179c2eac16826529b27c3a6301fbd/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#     'app_icon': '?cb=264615658',
#     'domain': '',
#     'url': 'https://www.behance.net/galleries/architecture/architecture-photography',
#     'ribbon': {'image': 'https://a5.behance.net/e14d6c7ba08179c2eac16826529b27c3a6301fbd/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#      'image_2x': 'https://a5.behance.net/e14d6c7ba08179c2eac16826529b27c3a6301fbd/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#      'image_3x': 'https://a5.behance.net/e14d6c7ba08179c2eac16826529b27c3a6301fbd/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#    'url': 'https://www.behance.net/galleries/architecture'},
#   {'featured_on': 1642856422,
#    'site': {'id': 295,
#     'parent_id': 0,
#     'name': 'Photoshop',
#     'key': 'photoshop',
#     'icon': 'https://a5.behance.net/e14d6c7ba08179c2eac16826529b27c3a6301fbd/img/galleries/icons/square/1x/photoshop.png?cb=264615658',
#     'app_icon': '?cb=264615658',
#     'domain': '',
#     'url': 'https://www.behance.net/galleries/Photoshop',
#     'ribbon': {'image': 'https://a5.behance.net/e14d6c7ba08179c2eac16826529b27c3a6301fbd/img/galleries/icons/ribbons/1x/photoshop.png?cb=264615658',
#      'image_2x': 'https://a5.behance.net/e14d6c7ba08179c2eac16826529b27c3a6301fbd/img/galleries/icons/ribbons/2x/photoshop@2x.png?cb=264615658',
#      'image_3x': 'https://a5.behance.net/e14d6c7ba08179c2eac16826529b27c3a6301fbd/img/galleries/icons/ribbons/3x/photoshop@3x.png?cb=264615658'}},
#    'url': 'https://www.behance.net/galleries/Photoshop'}],
#  'colors': [{'r': 23, 'g': 23, 'b': 23}]}

# %%
# name
result_items[0]['name']
# Out:
# 'CCBD\xa0Exhibition Pavilion | CCBD 展示中心'

# %%
# first name
result_items[0]['owners'][0]['first_name']
# Out:
# 'Xiao'

# %%
# last name
result_items[0]['owners'][0]['last_name']
# Out:
# 'Tan-谭啸'

# %%
# user name
result_items[0]['owners'][0]['username']
# Out:
# 'tan-xiao'

# %%
# country
result_items[0]['owners'][0]['country']
# Out:
# 'China'

# %%
# views
result_items[0]['owners'][0]['stats']['views']
# Out:
# 608844

# %%
# appreciations
result_items[0]['owners'][0]['stats']['appreciations']
# Out:
# 41925

# %%
# comments
result_items[0]['owners'][0]['stats']['comments']
# Out:
# 19

# %%
# url
result_items[0]['owners'][0]['url']
# Out:
# 'https://www.behance.net/tan-xiao'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
name = []
first_name = []
last_name = []
username = []
country = []
views = []
appreciations = []
comments = []
url = []

for result in result_items:
    # name
    name.append(result['name'])
    
    # first name
    first_name.append(result['owners'][0]['first_name'])
    
    # last name
    last_name.append(result['owners'][0]['last_name'])
    
    # username
    username.append(result['owners'][0]['username'])
    
    # country
    country.append(result['owners'][0]['country'])
    
    # views
    views.append(result['owners'][0]['stats']['views'])
    
    # appreciations
    appreciations.append(result['owners'][0]['stats']['appreciations'])
    
    # comments
    comments.append(result['owners'][0]['stats']['comments'])
    
    # url
    url.append(result['owners'][0]['url'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
df = pd.DataFrame({'name': name, 'first name': first_name, 'last name': last_name,
                   'username': username, 'country': country, 'views': views,
                   'appreciations': appreciations, 'comments': comments, 'url': url})

# %%
df
# Out:
#                                         name    first name       last name  \
# 0       CCBD Exhibition Pavilion | CCBD 展示中心          Xiao          Tan-谭啸
# 1                               Nice-Cordoba             .             MOT
# 2                                CITY MUSEUM        replus          bureau
# 3      ВХУТЕМАС-100. Архитектурный факультет          mila        silenina
# 4                    SPS COMMERCE / ZOTOV&CO        Andrey        Avdeenko
# 5                                       展厅空间           梦太初               -
# 6                                  Elsewhere        Maciek        Blaźniak
# 7                                    HONOR50        Thais          Varela
# 8                       Alfa Research Center           IND      architects
# 9             CASA SJ de Aguirre Arquitetura       Estúdio             RM2
# 10             Gili Gede | Unscripted design     Blackhaus          Studio
# 11                        Mural "Blck Vbrtn"           Lex            Zooz
# 12                                  Cihangir         Sezer         Alemdar
# 13                               1 DZIELNICA      Kolektyf             com
# 14             Radius Design｜[tei] by O'BOND          Hey!          Cheese
# 15                               ▪️M Stand▪️         Still           Young
# 16                      Tai Kwun - Hong Kong          Kris        Provoost
# 17                     Characters Houses Set          Dima      Kashtalyan
# 18                            HOK - New York          TMRW             inc
# 19      DAI CING GURUN /Chinese architecture       Hashira        YAMAMOTO
# 20  Student workshop - Wooden structures lab       Nicolai          Becker
# 21                            Cais do Cavaco       Jacinto        Monteiro
# 22                       Two Houses in Haifa         Ronen        Bekerman
# 23        interior of a residential building     Viktoriya           Sreda
# 24              Residential Area in Helsinki           BAK          studio
# 25           Contemporaine by Perkins & Will       Kseniya            Mogy
# 26                            Lynn landscape        DASTER       DASTOFSKY
# 27                 Office building in Paris.       WARRIOR             CGI
# 28                                    AVGVST       Dmitrii  Tsyrenshchikov
# 29            1000 Trees | ShanghaiArchStory   whyseeimage               _
# 30          Holiday Residence in Scandinavia           DIG           group
# 31                   the house of two planes          LUÍS        FERNANDO
# 32                           Lost in the Fog  Tomasz Artur           Bolek
# 33                               Ludia | lg2           lg2        Montreal
# 34                    Nationalparkcenter Thy           Kim      Høltermand
# 35                        Dentista Amsterdam           i29               .
# 36                     "NomNom" coffee table         Deniz           Aktay
# 37                           SJOEMANNSKIRKEN        Kirill        Vasilyev
# 38                    Prague Flat | Interior        Mihail        Grinchuk
# 39                                  THERE BE    superkomma               ™
# 40                   Shadovvs : Matte Black.          Matt        W. Moore
# 41                    VIPP SHELTER ANIMATION        Serkan           Çelik
# 42                           Touch Of Matcha       Nikolay           Yarin
# 43                          Almaza Bay Villa          Nour        El Refai
# 44                         AS House Interior          Koma   Visualization
# 45                                   woodspa         Yuriy           Ataev
# 46                               Docks Works      Walk the            Room
# 47                                  RED WALL        Thais          Varela
#
#               username             country    views  appreciations  comments  \
# 0             tan-xiao               China   608844          41925        19
# 1           estudiomot           Argentina    89480          11399        20
# 2         replusbureau             Ukraine     3773            778         0
# 3         milasilenina  Russian Federation    90216           9467         2
# 4       AndreyAvdeenko             Ukraine   706196          61445        87
# 5       a9524500843001               China    88058           5611        35
# 6       maciekblazniak              Poland   150302          17207        66
# 7       azulclacasibla               Spain    73967           8959        13
# 8        indarchitects  Russian Federation   228818          17059         6
# 9           estudiorm2              Brazil     4694            587         0
# 10             blkhaus              Brazil   188336          18106        19
# 11             LexZooz             Estonia    69439           9823       110
# 12        sezerdar96fb              Turkey     2854            464         0
# 13            kolektyf              Poland   234509          18002        20
# 14           heycheese       Taiwan Region  5424293         257967        29
# 15            1b83e145               China    45344           3854         0
# 16        krisprovoost           Hong Kong   296713          25179       168
# 17          Kashtalyan             Ukraine   394092          42515       401
# 18          tomorrowab              Sweden   425459          45592         1
# 19     hashilaboratory               Japan    49296           7374       773
# 20           Looma_vis             Germany    65775           7218        50
# 21  MetroCubicoDigital            Portugal   243511          29334        83
# 22       ronenbekerman              Israel   354586          31597       440
# 23          sredave03e  Russian Federation    23430           3265        57
# 24      BAKstudioh5bd2  Russian Federation    48895           6339        33
# 25               2kviz              Turkey    61183           7432       160
# 26          oflodaster            Colombia     2268            264         1
# 27         warrior-cgi             Armenia    59544           7772        25
# 28       Tsyrencshikov  Russian Federation   243415          20625         3
# 29         whyseeimage               China   118698           9899        49
# 30            diggroup              Poland    90727          11350        20
# 31           luisarqui              Brazil    29832           3870         7
# 32         TomaszBolek              Poland   234171          23219       350
# 33         lg2montreal              Canada  1724279         141027         0
# 34          Holtermand             Denmark  2258357         139338       523
# 35                 i29         Netherlands   389227          26806         0
# 36        dezin_design             Germany    30769           3217        31
# 37          bairdesign             Ukraine    13115           1854        21
# 38          grinchuk_m  Russian Federation   160828          12230       188
# 39          superkomma  Korea, Republic of    12782           1343         1
# 40         MWMGRAPHICS       United States   436473          38274       118
# 41         serkancelik              Turkey   133011          23624        68
# 42        nikolayyarin  Russian Federation   117636          12033       110
# 43         nourelrefai               Egypt   282483          20974         3
# 44   komavisualization           Indonesia   197885          15259       159
# 45              fox287  Russian Federation    89376          10946        12
# 46         walktheroom              Sweden   378997          30807       133
# 47      azulclacasibla               Spain    73967           8959        13
#
#                                            url
# 0             https://www.behance.net/tan-xiao
# 1           https://www.behance.net/estudiomot
# 2         https://www.behance.net/replusbureau
# 3         https://www.behance.net/milasilenina
# 4       https://www.behance.net/AndreyAvdeenko
# 5       https://www.behance.net/a9524500843001
# 6       https://www.behance.net/maciekblazniak
# 7       https://www.behance.net/azulclacasibla
# 8        https://www.behance.net/indarchitects
# 9           https://www.behance.net/estudiorm2
# 10             https://www.behance.net/blkhaus
# 11             https://www.behance.net/LexZooz
# 12        https://www.behance.net/sezerdar96fb
# 13            https://www.behance.net/kolektyf
# 14           https://www.behance.net/heycheese
# 15            https://www.behance.net/1b83e145
# 16        https://www.behance.net/krisprovoost
# 17          https://www.behance.net/Kashtalyan
# 18          https://www.behance.net/tomorrowab
# 19     https://www.behance.net/hashilaboratory
# 20           https://www.behance.net/Looma_vis
# 21  https://www.behance.net/MetroCubicoDigital
# 22       https://www.behance.net/ronenbekerman
# 23          https://www.behance.net/sredave03e
# 24      https://www.behance.net/BAKstudioh5bd2
# 25               https://www.behance.net/2kviz
# 26          https://www.behance.net/oflodaster
# 27         https://www.behance.net/warrior-cgi
# 28       https://www.behance.net/Tsyrencshikov
# 29         https://www.behance.net/whyseeimage
# 30            https://www.behance.net/diggroup
# 31           https://www.behance.net/luisarqui
# 32         https://www.behance.net/TomaszBolek
# 33         https://www.behance.net/lg2montreal
# 34          https://www.behance.net/Holtermand
# 35                 https://www.behance.net/i29
# 36        https://www.behance.net/dezin_design
# 37          https://www.behance.net/bairdesign
# 38          https://www.behance.net/grinchuk_m
# 39          https://www.behance.net/superkomma
# 40         https://www.behance.net/MWMGRAPHICS
# 41         https://www.behance.net/serkancelik
# 42        https://www.behance.net/nikolayyarin
# 43         https://www.behance.net/nourelrefai
# 44   https://www.behance.net/komavisualization
# 45              https://www.behance.net/fox287
# 46         https://www.behance.net/walktheroom
# 47      https://www.behance.net/azulclacasibla

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %%
headers = {
    'authority': 'www.behance.net',
    'accept': '*/*',
    'x-bcp': '0e94cad1-98bc-4948-9193-434abe97f815',
    'x-requested-with': 'XMLHttpRequest',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36',
    'sec-gpc': '1',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': 'gk_suid=29269953; gki=%7B%22feature_stock_rail%22%3Afalse%7D; bcp=0e94cad1-98bc-4948-9193-434abe97f815; AMCVS_9E1005A551ED61CA0A490D45%40AdobeOrg=1; gpv=behance.net:search:projects; s_cc=true; OptanonConsent=isIABGlobal=false&datestamp=Fri+Jan+21+2022+18%3A50%3A24+GMT%2B0300+(%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D0%B0%2C+%D1%81%D1%82%D0%B0%D0%BD%D0%B4%D0%B0%D1%80%D1%82%D0%BD%D0%BE%D0%B5+%D0%B2%D1%80%D0%B5%D0%BC%D1%8F)&version=6.9.0&hosts=&consentId=d0a29a75-eba3-4af9-93aa-6089e0c21cec&interactionCount=0&landingPath=https%3A%2F%2Fwww.behance.net%2F&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1; feds_privacy_consent={"hasUserProvidedConsent":true,"userHasCustomConsent":false}; s_sq=%5B%5BB%5D%5D; sign_up_prompt=true; AMCV_9E1005A551ED61CA0A490D45%40AdobeOrg=870038026%7CMCMID%7C56586488518047349773733653051510070332%7CMCAID%7CNONE%7CMCOPTOUT-1642787470s%7CNONE%7CvVersion%7C5.0.0',
}

name = []
first_name = []
last_name = []
username = []
country = []
views = []
appreciations = []
comments = []
url = []

# scrape 10 pages

for i in range(0, 480, 48):
    params = (
        ('content', 'projects'),
        ('field', 'architecture'),
        ('ordinal', str(i)),
    )

    # response variable for the get request
    response = requests.get('https://www.behance.net/search', headers=headers, params=params)

    # json object
    results_json = response.json()

    # list of results
    result_items = results_json['search']['content']['projects']

    for result in result_items:
        # name
        name.append(result['name'])
        
        # first name
        first_name.append(result['owners'][0]['first_name'])
        
        # last name
        last_name.append(result['owners'][0]['last_name'])
        
        # username
        username.append(result['owners'][0]['username'])
        
        # country
        country.append(result['owners'][0]['country'])
        
        # views
        views.append(result['owners'][0]['stats']['views'])
        
        # appreciations
        appreciations.append(result['owners'][0]['stats']['appreciations'])
        
        # comments
        comments.append(result['owners'][0]['stats']['comments'])
        
        # url
        url.append(result['owners'][0]['url'])

# %%
df = pd.DataFrame({'name': name, 'first name': first_name, 'last name': last_name,
                   'username': username, 'country': country, 'views': views,
                   'appreciations': appreciations, 'comments': comments, 'url': url})

# %%
df
# Out:
#                                       name first name  last name  \
# 0     CCBD Exhibition Pavilion | CCBD 展示中心       Xiao     Tan-谭啸
# 1                             Nice-Cordoba          .        MOT
# 2                              CITY MUSEUM     replus     bureau
# 3    ВХУТЕМАС-100. Архитектурный факультет       mila   silenina
# 4                  SPS COMMERCE / ZOTOV&CO     Andrey   Avdeenko
# ..                                     ...        ...        ...
# 475                            ALPHA HOUSE      RUBEN     MUEDRA
# 476                          Golden Brains     Alexey  Kozhenkov
# 477                   The Lonely Astronaut      Karen     Jerzyk
# 478                        Iglesia moderna       Marc       Pons
# 479                  MY FLOW CAFE INTERIOR      Akhat   Baimenov
#
#                username             country   views  appreciations  comments  \
# 0              tan-xiao               China  608844          41925        19
# 1            estudiomot           Argentina   89480          11399        20
# 2          replusbureau             Ukraine    3773            778         0
# 3          milasilenina  Russian Federation   90216           9467         2
# 4        AndreyAvdeenko             Ukraine  706196          61445        87
# ..                  ...                 ...     ...            ...       ...
# 475         rubenmuedra               Spain   63060           6747        15
# 476           kozhenkov  Russian Federation   50575           5368        43
# 477    karenjerzykphoto       United States   65443           6802         6
# 478            emmepons               Spain   45114          19315       853
# 479  up2date-architects          Kazakhstan  107961           7994        11
#
#                                             url
# 0              https://www.behance.net/tan-xiao
# 1            https://www.behance.net/estudiomot
# 2          https://www.behance.net/replusbureau
# 3          https://www.behance.net/milasilenina
# 4        https://www.behance.net/AndreyAvdeenko
# ..                                          ...
# 475         https://www.behance.net/rubenmuedra
# 476           https://www.behance.net/kozhenkov
# 477    https://www.behance.net/karenjerzykphoto
# 478            https://www.behance.net/emmepons
# 479  https://www.behance.net/up2date-architects
#
# [480 rows x 9 columns]

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
df.to_excel('pictures_multiple_pages.xlsx', engine='xlsxwriter', index=False)
