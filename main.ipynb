# %% [markdown]
# #### Step 1 - Imports

# %%
import requests

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.behance.net',
    'accept': '*/*',
    'x-bcp': '0e94cad1-98bc-4948-9193-434abe97f815',
    'x-requested-with': 'XMLHttpRequest',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36',
    'sec-gpc': '1',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': 'gk_suid=29269953; gki=%7B%22feature_stock_rail%22%3Afalse%7D; bcp=0e94cad1-98bc-4948-9193-434abe97f815; AMCVS_9E1005A551ED61CA0A490D45%40AdobeOrg=1; gpv=behance.net:search:projects; s_cc=true; OptanonConsent=isIABGlobal=false&datestamp=Fri+Jan+21+2022+18%3A50%3A24+GMT%2B0300+(%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D0%B0%2C+%D1%81%D1%82%D0%B0%D0%BD%D0%B4%D0%B0%D1%80%D1%82%D0%BD%D0%BE%D0%B5+%D0%B2%D1%80%D0%B5%D0%BC%D1%8F)&version=6.9.0&hosts=&consentId=d0a29a75-eba3-4af9-93aa-6089e0c21cec&interactionCount=0&landingPath=https%3A%2F%2Fwww.behance.net%2F&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1; feds_privacy_consent={"hasUserProvidedConsent":true,"userHasCustomConsent":false}; s_sq=%5B%5BB%5D%5D; sign_up_prompt=true; AMCV_9E1005A551ED61CA0A490D45%40AdobeOrg=870038026%7CMCMID%7C56586488518047349773733653051510070332%7CMCAID%7CNONE%7CMCOPTOUT-1642787470s%7CNONE%7CvVersion%7C5.0.0',
}

params = (
    ('content', 'projects'),
    ('field', 'architecture'),
    ('ordinal', '0'),
)

response = requests.get('https://www.behance.net/search', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['search', 'creativeFields', 'tools', 'schools'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
results_json['search']
# Out:
# {'filters': {'search': None,
#   'sort': 'recommended',
#   'time': 'week',
#   'field': 'architecture',
#   'color_hex': None,
#   'schools': None,
#   'tools': None,
#   'user_tags': None,
#   'country': None,
#   'state': None,
#   'city': None,
#   'stateCode': None},
#  'creativeFields': {'popular': [{'label': 'Анимационный дизайн',
#     'value': 'motion graphics',
#     'id': 63},
#    {'label': 'Арт-директор', 'value': 'art direction', 'id': 5},
#    {'label': 'Архитектура', 'value': 'architecture', 'id': 4},
#    {'label': 'Бренды', 'value': 'branding', 'id': 109},
#    {'label': 'Веб-дизайн', 'value': 'web design', 'id': 102},
#    {'label': 'Графический дизайн', 'value': 'graphic design', 'id': 44},
#    {'label': 'Иллюстрация', 'value': 'illustration', 'id': 48},
#    {'label': 'Мода', 'value': 'fashion', 'id': 37},
#    {'label': 'Польз. интерфейс', 'value': 'ui/ux', 'id': 132},
#    {'label': 'Проектир. взаимодействия',
#     'value': 'interaction design',
#     'id': 51},
#    {'label': 'Промышленный дизайн', 'value': 'industrial design', 'id': 49},
#    {'label': 'Фотография', 'value': 'photography', 'id': 73}],
#   'alphabetized': [{'name': '#',
#     'entries': [{'label': '3D-арт', 'value': '3d art', 'id': 145},
#      {'label': '3D-моделирование', 'value': '3d modeling', 'id': 147},
#      {'label': '3D-анимация', 'value': '3d motion', 'id': 149}]},
#    {'name': 'a', 'entries': [{'label': 'AR/VR', 'value': 'ar/vr', 'id': 141}]},
#    {'name': 'c', 'entries': [{'label': 'CGI', 'value': 'cgi', 'id': 241}]},
#    {'name': 's',
#     'entries': [{'label': 'Students', 'value': 'students', 'id': 143}]},
#    {'name': 'а',
#     'entries': [{'label': 'Анимация', 'value': 'animation', 'id': 3},
#      {'label': 'Архитектура', 'value': 'architecture', 'id': 4},
#      {'label': 'Архитектурная концепция',
#       'value': 'architecture concept',
#       'id': 157},
#      {'label': 'Архитектурная фотография',
#       'value': 'architecture photography',
#       'id': 159},
#      {'label': 'Архитектурная визуализация',
#       'value': 'architecture visualization',
#       'id': 161},
#      {'label': 'Арт-директор', 'value': 'art direction', 'id': 5},
#      {'label': 'Анимация GIF', 'value': 'gif animation', 'id': 191},
#      {'label': 'Анимационный дизайн', 'value': 'motion graphics', 'id': 63}]},
#    {'name': 'б',
#     'entries': [{'label': 'Бренды', 'value': 'branding', 'id': 109}]},
#    {'name': 'в',
#     'entries': [{'label': 'Визуальные эффекты',
#       'value': 'visual effects',
#       'id': 120},
#      {'label': 'Визуализация', 'value': 'visualization', 'id': 235},
#      {'label': 'Веб-дизайн', 'value': 'web design', 'id': 102}]},
#    {'name': 'г',
#     'entries': [{'label': 'Граффити', 'value': 'graffiti', 'id': 43},
#      {'label': 'Графический дизайн', 'value': 'graphic design', 'id': 44}]},
#    {'name': 'д',
#     'entries': [{'label': 'Дизайн автомобилей',
#       'value': 'automotive design',
#       'id': 130},
#      {'label': 'Дизайн персонажей', 'value': 'character design', 'id': 124},
#      {'label': 'Дизайн костюмов', 'value': 'costume design', 'id': 20},
#      {'label': 'Дизайн изданий', 'value': 'editorial design', 'id': 32},
#      {'label': 'Дизайн выставок', 'value': 'exhibition design', 'id': 36},
#      {'label': 'Дизайн модной одежды', 'value': 'fashion design', 'id': 177},
#      {'label': 'Дизайн мебели', 'value': 'furniture design', 'id': 40},
#      {'label': 'Дизайн значков', 'value': 'icon design', 'id': 131},
#      {'label': 'Дизайн интерьера', 'value': 'interior design', 'id': 52},
#      {'label': 'Дизайн ювелирн. украшений',
#       'value': 'jewelry design',
#       'id': 53},
#      {'label': 'Дизайн этикеток', 'value': 'label design', 'id': 195},
#      {'label': 'Дизайн логотипов', 'value': 'logo design', 'id': 199},
#      {'label': 'Дизайн упаковки музыкальных альбомов',
#       'value': 'music packaging',
#       'id': 209},
#      {'label': 'Документы', 'value': 'paperworks', 'id': 211},
#      {'label': 'Дизайн узоров', 'value': 'pattern design', 'id': 69},
#      {'label': 'Дизайн плакатов', 'value': 'poster design', 'id': 215},
#      {'label': 'Дизайн продуктов', 'value': 'product design', 'id': 79},
#      {'label': 'Дизайн реквизита', 'value': 'props design', 'id': 221},
#      {'label': 'Дизайн обуви', 'value': 'shoe design', 'id': 223},
#      {'label': 'Дизайн структуры поверхности',
#       'value': 'surface design',
#       'id': 229},
#      {'label': 'Дизайн футболок', 'value': 't-shirt design', 'id': 231},
#      {'label': 'Дизайн игрушек', 'value': 'toy design', 'id': 126},
#      {'label': 'Дизайн шрифтов', 'value': 'type design', 'id': 233},
#      {'label': 'Дизайн окон', 'value': 'window design', 'id': 237}]},
#    {'name': 'з',
#     'entries': [{'label': 'Звуковой дизайн',
#       'value': 'sound design',
#       'id': 118}]},
#    {'name': 'и',
#     'entries': [{'label': 'Иллюстрации на тему моды',
#       'value': 'fashion illustration',
#       'id': 179},
#      {'label': 'Изобразительные искусства', 'value': 'fine arts', 'id': 112},
#      {'label': 'Игровой дизайн', 'value': 'game design', 'id': 41},
#      {'label': 'Иллюстрация', 'value': 'illustration', 'id': 48},
#      {'label': 'Инфографика', 'value': 'infographic', 'id': 193},
#      {'label': 'Информац. архитектура',
#       'value': 'information architecture',
#       'id': 50},
#      {'label': 'Исполнит. виды искусства',
#       'value': 'performing arts',
#       'id': 70}]},
#    {'name': 'к',
#     'entries': [{'label': 'Красота', 'value': 'beauty photography', 'id': 163},
#      {'label': 'Каллиграфия', 'value': 'calligraphy', 'id': 133},
#      {'label': 'Кинематография', 'value': 'cinematography', 'id': 12},
#      {'label': 'Коллаж', 'value': 'collage', 'id': 165},
#      {'label': 'Комикс', 'value': 'comic', 'id': 169},
#      {'label': 'Концептуальное искусство', 'value': 'concept art', 'id': 171},
#      {'label': 'Копирайтинг', 'value': 'copywriting', 'id': 19},
#      {'label': 'Кустарные промыслы', 'value': 'crafts', 'id': 21},
#      {'label': 'Креативный директор',
#       'value': 'creative direction',
#       'id': 137},
#      {'label': 'Кулинарное искусство', 'value': 'culinary arts', 'id': 23},
#      {'label': 'Киноиндустрия', 'value': 'film', 'id': 38},
#      {'label': 'Креативный макияж', 'value': 'makeup arts', 'id': 201}]},
#    {'name': 'л',
#     'entries': [{'label': 'Ландшафтный дизайн',
#       'value': 'landscape design',
#       'id': 55}]},
#    {'name': 'м',
#     'entries': [{'label': 'Мода', 'value': 'fashion', 'id': 37},
#      {'label': 'Модная фотография', 'value': 'fashion photography', 'id': 181},
#      {'label': 'Макияж', 'value': 'makeup', 'id': 203},
#      {'label': 'Моделирование', 'value': 'modeling', 'id': 207},
#      {'label': 'Музыка', 'value': 'music', 'id': 64}]},
#    {'name': 'о',
#     'entries': [{'label': 'Одежда', 'value': 'apparel', 'id': 155},
#      {'label': 'Оформление сцены', 'value': 'set design', 'id': 87}]},
#    {'name': 'п',
#     'entries': [{'label': 'Промышленный дизайн',
#       'value': 'industrial design',
#       'id': 49},
#      {'label': 'Проектир. взаимодействия',
#       'value': 'interaction design',
#       'id': 51},
#      {'label': 'Программирование', 'value': 'programming', 'id': 123},
#      {'label': 'Польз. интерфейс', 'value': 'ui/ux', 'id': 132},
#      {'label': 'Писательское искусство', 'value': 'writing', 'id': 105}]},
#    {'name': 'р',
#     'entries': [{'label': 'Реклама', 'value': 'advertising', 'id': 108},
#      {'label': 'Рекламная фотография',
#       'value': 'advertising photography',
#       'id': 151},
#      {'label': 'Разработка приложений', 'value': 'app design', 'id': 153},
#      {'label': 'Раскраска', 'value': 'coloring', 'id': 167},
#      {'label': 'Режиссура', 'value': 'directing', 'id': 28},
#      {'label': 'Рисунок', 'value': 'drawing', 'id': 110},
#      {'label': 'Редактирование', 'value': 'editing', 'id': 31},
#      {'label': 'Ретушь изображений из мира моды',
#       'value': 'fashion retouching',
#       'id': 183},
#      {'label': 'Рисование', 'value': 'painting', 'id': 67},
#      {'label': 'Ретушь', 'value': 'retouching', 'id': 136},
#      {'label': 'Раскадровка', 'value': 'storyboarding', 'id': 91},
#      {'label': 'Работа по дереву', 'value': 'woodworking', 'id': 239}]},
#    {'name': 'с',
#     'entries': [{'label': 'Стилистика моды',
#       'value': 'fashion styling',
#       'id': 93},
#      {'label': 'Создание композиций из цветов',
#       'value': 'flower arrangement',
#       'id': 185},
#      {'label': 'Стилизация еды', 'value': 'food styling', 'id': 189},
#      {'label': 'Стилизация фотографий',
#       'value': 'photography styling',
#       'id': 213},
#      {'label': 'Сопоставление проекций',
#       'value': 'projection mapping',
#       'id': 219},
#      {'label': 'Скульптура', 'value': 'sculpting', 'id': 86},
#      {'label': 'Создание эскизов', 'value': 'sketching', 'id': 225},
#      {'label': 'Стилевое оформление', 'value': 'styleframing', 'id': 227}]},
#    {'name': 'т',
#     'entries': [{'label': 'Тестовая фотография модели',
#       'value': 'model test photography',
#       'id': 205},
#      {'label': 'Текстильный дизайн', 'value': 'textile design', 'id': 95},
#      {'label': 'Типографика', 'value': 'typography', 'id': 97}]},
#    {'name': 'у',
#     'entries': [{'label': 'Упаковка', 'value': 'packaging', 'id': 66},
#      {'label': 'Уличное искусство', 'value': 'street art', 'id': 135}]},
#    {'name': 'ф',
#     'entries': [{'label': 'Фотография продуктов питания',
#       'value': 'food photography',
#       'id': 187},
#      {'label': 'Фотография', 'value': 'photography', 'id': 73},
#      {'label': 'Фотожурналистика', 'value': 'photojournalism', 'id': 74},
#      {'label': 'Фотография продуктов',
#       'value': 'product photography',
#       'id': 217}]},
#    {'name': 'ц',
#     'entries': [{'label': 'Цифровое искусство',
#       'value': 'digital art',
#       'id': 122},
#      {'label': 'Цифровая живопись', 'value': 'digital painting', 'id': 173}]},
#    {'name': 'ш',
#     'entries': [{'label': 'Шрифтовая композиция',
#       'value': 'lettering',
#       'id': 197}]},
#    {'name': 'э',
#     'entries': [{'label': 'Экологическая графика',
#       'value': 'environmental graphics',
#       'id': 175}]}],
#   'isInitialized': True},
#  'isFetching': {'allResults': False,
#   'projects': False,
#   'images': False,
#   'users': False,
#   'collections': False,
#   'moodboards': False},
#  'isLoadingMore': False,
#  'isInitialized': True,
#  'hasMore': True,
#  'content': {'projects': [{'id': 133905077,
#     'name': 'CITY MUSEUM',
#     'published_on': 1640598028,
#     'created_on': 1640597922,
#     'modified_on': 1642734021,
#     'url': 'https://www.behance.net/gallery/133905077/CITY-MUSEUM',
#     'slug': 'CITY-MUSEUM',
#     'privacy': 'public',
#     'fields': ['Architecture', 'Interior Design'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/4bb18f133905077.Y3JvcCwxMjY4LDk5Miw2NSww.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/4bb18f133905077.Y3JvcCwxMjY4LDk5Miw2NSww.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/4bb18f133905077.Y3JvcCwxMjY4LDk5Miw2NSww.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/4bb18f133905077.Y3JvcCwxMjY4LDk5Miw2NSww.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/4bb18f133905077.Y3JvcCwxMjY4LDk5Miw2NSww.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/4bb18f133905077.Y3JvcCwxMjY4LDk5Miw2NSww.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/4bb18f133905077.Y3JvcCwxMjY4LDk5Miw2NSww.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 1141154209,
#       'first_name': 'replus',
#       'last_name': 'bureau',
#       'username': 'replusbureau',
#       'city': 'Lviv',
#       'state': '',
#       'country': 'Ukraine',
#       'location': 'Lviv, Ukraine',
#       'company': 'replus bureau',
#       'occupation': 'architecture and design bureau',
#       'created_on': 1638441284,
#       'url': 'https://www.behance.net/replusbureau',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/4145ee1141154209.61a8a5e95c5ca.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/4145ee1141154209.61a8a5e95c5ca.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/4145ee1141154209.61a8a5e95c5ca.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/4145ee1141154209.61a8a5e95c5ca.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/4145ee1141154209.61a8a5e95c5ca.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/4145ee1141154209.61a8a5e95c5ca.jpg'},
#       'display_name': 'replus bureau',
#       'fields': ['Architecture', 'Interior Design'],
#       'has_default_image': 0,
#       'website': 'http://replusbureau.com/',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/5d6e964836b77d306002ea339e07d6e8/fae88ab3-8e58-4855-bc67-6909a09366e3_rwc_-7x3146x9504x1664x9504.jpg?h=ce0374ef2f2dae4eee334011bec358fb',
#       'has_premium_access': False,
#       'stats': {'followers': 344,
#        'following': 4,
#        'comments': 0,
#        'appreciations': 778,
#        'views': 3773}},
#      {'id': 8235985,
#       'first_name': 'Andrey',
#       'last_name': 'Bezuglov',
#       'username': 'bezuglov',
#       'city': 'Kiev',
#       'state': '',
#       'country': 'Ukraine',
#       'location': 'Kiev, Ukraine',
#       'company': 'Bezuglov.ua',
#       'occupation': 'Photographer',
#       'created_on': 1412123500,
#       'url': 'https://www.behance.net/bezuglov',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/c8419f8235985.54dd3621a9ac0.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/c8419f8235985.54dd3621a9ac0.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/c8419f8235985.54dd3621a9ac0.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/c8419f8235985.54dd3621a9ac0.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/c8419f8235985.54dd3621a9ac0.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/c8419f8235985.54dd3621a9ac0.jpg'},
#       'display_name': 'Andrey Bezuglov',
#       'fields': ['Interior Design', 'Architecture', 'Industrial Design'],
#       'has_default_image': 0,
#       'website': 'www.bezuglov.ua',
#       'banner_image_url': '',
#       'has_premium_access': False,
#       'stats': {'followers': 12730,
#        'following': 6,
#        'comments': 0,
#        'appreciations': 69251,
#        'views': 807757}}],
#     'stats': {'views': 1802, 'appreciations': 318, 'comments': 5},
#     'conceived_on': 1640563200,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1642734021,
#       'site': {'id': 30,
#        'parent_id': 5,
#        'name': 'Дизайн интерьера',
#        'key': 'interior',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': 'interiordesignserved.com',
#        'url': 'https://www.behance.net/galleries/architecture/interior-design',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 104, 'g': 100, 'b': 94}]},
#    {'id': 123019737,
#     'name': 'ВХУТЕМАС-100. Архитектурный факультет',
#     'published_on': 1625676644,
#     'created_on': 1625668303,
#     'modified_on': 1642726815,
#     'url': 'https://www.behance.net/gallery/123019737/vhutemas-100-arhitekturnyj-fakultet',
#     'slug': 'vhutemas-100-arhitekturnyj-fakultet',
#     'privacy': 'public',
#     'fields': ['Graphic Design', 'Architecture'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/09a5eb123019737.Y3JvcCwxMDA3LDc4OCwxOTcsMA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/09a5eb123019737.Y3JvcCwxMDA3LDc4OCwxOTcsMA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/09a5eb123019737.Y3JvcCwxMDA3LDc4OCwxOTcsMA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/09a5eb123019737.Y3JvcCwxMDA3LDc4OCwxOTcsMA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/09a5eb123019737.Y3JvcCwxMDA3LDc4OCwxOTcsMA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/09a5eb123019737.Y3JvcCwxMDA3LDc4OCwxOTcsMA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/09a5eb123019737.Y3JvcCwxMDA3LDc4OCwxOTcsMA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 10516321,
#       'first_name': 'mila',
#       'last_name': 'silenina',
#       'username': 'milasilenina',
#       'city': 'Moscow',
#       'state': '',
#       'country': 'Russian Federation',
#       'location': 'Moscow, Russian Federation',
#       'company': 'Holystick',
#       'occupation': 'Partner, Art director',
#       'created_on': 1419447612,
#       'url': 'https://www.behance.net/milasilenina',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/d5460610516321.60e5ad4d198ee.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/d5460610516321.60e5ad4d198ee.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/d5460610516321.60e5ad4d198ee.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/d5460610516321.60e5ad4d198ee.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/d5460610516321.60e5ad4d198ee.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/d5460610516321.60e5ad4d198ee.jpg'},
#       'display_name': 'mila silenina',
#       'fields': ['Graphic Design', 'Typography'],
#       'has_default_image': 0,
#       'website': 'http://holystick.design',
#       'banner_image_url': '',
#       'has_premium_access': False,
#       'stats': {'followers': 1564,
#        'following': 66,
#        'comments': 2,
#        'appreciations': 9467,
#        'views': 90216}},
#      {'id': 9118491,
#       'first_name': 'Yulia',
#       'last_name': 'Kondrateva',
#       'username': 'yulia_kondrateva',
#       'city': 'Moscow',
#       'state': '',
#       'country': 'Russian Federation',
#       'location': 'Moscow, Russian Federation',
#       'company': '',
#       'occupation': 'Graphic designer',
#       'created_on': 1413846075,
#       'url': 'https://www.behance.net/yulia_kondrateva',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/3c8c5d9118491.57dd38a26c912.png',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/3c8c5d9118491.57dd38a26c912.png',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/3c8c5d9118491.57dd38a26c912.png',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/3c8c5d9118491.57dd38a26c912.png',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/3c8c5d9118491.57dd38a26c912.png',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/3c8c5d9118491.57dd38a26c912.png'},
#       'display_name': 'Yulia Kondrateva',
#       'fields': ['Graphic Design', 'Exhibition Design'],
#       'has_default_image': 0,
#       'website': '',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/c7b1b66fb6a06875d58d793707348627/74fb5bca-b637-452e-9681-ede82afc7c03_rwc_682x530x1488x244x2560.png?h=461654246728582f987908e42bf31731',
#       'has_premium_access': False,
#       'stats': {'followers': 522,
#        'following': 90,
#        'comments': 1,
#        'appreciations': 3844,
#        'views': 42743}},
#      {'id': 1929003,
#       'first_name': 'Yana',
#       'last_name': 'Etkina',
#       'username': 'etkina',
#       'city': 'Moscow',
#       'state': '',
#       'country': 'Russian Federation',
#       'location': 'Moscow, Russian Federation',
#       'company': 'Holystick',
#       'occupation': 'co-founder',
#       'created_on': 1354906729,
#       'url': 'https://www.behance.net/etkina',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/7d64731929003.570e4dfbbbce5.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/7d64731929003.570e4dfbbbce5.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/7d64731929003.570e4dfbbbce5.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/7d64731929003.570e4dfbbbce5.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/7d64731929003.570e4dfbbbce5.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/7d64731929003.570e4dfbbbce5.jpg'},
#       'display_name': 'Yana Etkina',
#       'fields': ['Graphic Design', 'Editorial Design', 'Typography'],
#       'has_default_image': 0,
#       'website': 'holystick.design',
#       'banner_image_url': '',
#       'has_premium_access': False,
#       'stats': {'followers': 287,
#        'following': 35,
#        'comments': 2,
#        'appreciations': 3005,
#        'views': 28852}},
#      {'id': 716221741,
#       'first_name': 'Holystick',
#       'last_name': 'design',
#       'username': 'holystickdesign',
#       'city': 'Moscow',
#       'state': '',
#       'country': 'Russian Federation',
#       'location': 'Moscow, Russian Federation',
#       'company': '',
#       'occupation': '',
#       'created_on': 1601978549,
#       'url': 'https://www.behance.net/holystickdesign',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/7e9d6f716221741.5f7c40ec073fe.png',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/7e9d6f716221741.5f7c40ec073fe.png',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/7e9d6f716221741.5f7c40ec073fe.png',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/7e9d6f716221741.5f7c40ec073fe.png',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/7e9d6f716221741.5f7c40ec073fe.png',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/7e9d6f716221741.5f7c40ec073fe.png'},
#       'display_name': 'Holystick design',
#       'fields': ['Graphic Design', 'Typography', 'Exhibition Design'],
#       'has_default_image': 0,
#       'website': 'http://holystick.design',
#       'banner_image_url': '',
#       'has_premium_access': False,
#       'stats': {'followers': 464,
#        'following': 11,
#        'comments': 0,
#        'appreciations': 3056,
#        'views': 27463}}],
#     'stats': {'views': 6063, 'appreciations': 602, 'comments': 39},
#     'conceived_on': 1625616000,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1626204649,
#       'site': {'id': 99,
#        'parent_id': 2,
#        'name': 'Выставки и вывески',
#        'key': 'exhibition&signage',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/gallery-2.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/graphic-design/exhibition-and-signage',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/graphic-design.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/graphic-design@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/graphic-design@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/graphic-design'},
#      {'featured_on': 1642726815,
#       'site': {'id': 299,
#        'parent_id': 0,
#        'name': 'InDesign',
#        'key': 'AId',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/AId.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/InDesign',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/indesign.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/indesign@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/indesign@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/InDesign'}],
#     'colors': [{'r': 228, 'g': 232, 'b': 232}]},
#    {'id': 107240345,
#     'name': 'SPS COMMERCE / ZOTOV&CO',
#     'published_on': 1604489108,
#     'created_on': 1604489102,
#     'modified_on': 1642726814,
#     'url': 'https://www.behance.net/gallery/107240345/SPS-COMMERCE-ZOTOV-CO',
#     'slug': 'SPS-COMMERCE-ZOTOV-CO',
#     'privacy': 'public',
#     'fields': ['Architecture', 'Photography', 'Interior Design'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/ed1296107240345.Y3JvcCwxNzQ1LDEzNjUsMTg1LDA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/ed1296107240345.Y3JvcCwxNzQ1LDEzNjUsMTg1LDA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/ed1296107240345.Y3JvcCwxNzQ1LDEzNjUsMTg1LDA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/ed1296107240345.Y3JvcCwxNzQ1LDEzNjUsMTg1LDA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/ed1296107240345.Y3JvcCwxNzQ1LDEzNjUsMTg1LDA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/ed1296107240345.Y3JvcCwxNzQ1LDEzNjUsMTg1LDA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/ed1296107240345.Y3JvcCwxNzQ1LDEzNjUsMTg1LDA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 58884227,
#       'first_name': 'Andrey',
#       'last_name': 'Avdeenko',
#       'username': 'AndreyAvdeenko',
#       'city': 'Kyiv',
#       'state': '',
#       'country': 'Ukraine',
#       'location': 'Kyiv, Ukraine',
#       'company': 'Andrey Avdeenko photographer',
#       'occupation': 'Architectural and interior photographer. Worldwide.',
#       'created_on': 1482860577,
#       'url': 'https://www.behance.net/AndreyAvdeenko',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/942f4b58884227.58a83b7b23ffd.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/942f4b58884227.58a83b7b23ffd.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/942f4b58884227.58a83b7b23ffd.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/942f4b58884227.58a83b7b23ffd.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/942f4b58884227.58a83b7b23ffd.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/942f4b58884227.58a83b7b23ffd.jpg'},
#       'display_name': 'Andrey Avdeenko',
#       'fields': ['Interior Design', 'Architecture', 'Photography'],
#       'has_default_image': 0,
#       'website': '',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/5980be06a1364447d5dd9d5648706f36/f2386674-7ae7-4333-87ed-e4d60f0d09f6_rwc_214x0x2772x410x3200.jpg?h=63eb218c78e9c7e531c5023d661607a3',
#       'has_premium_access': False,
#       'stats': {'followers': 20396,
#        'following': 91,
#        'comments': 87,
#        'appreciations': 61445,
#        'views': 706196}},
#      {'id': 1084199295,
#       'first_name': 'ZOTOV&CO',
#       'last_name': 'Architecture bureau',
#       'username': 'zotovandco',
#       'city': 'Kyiv',
#       'state': '',
#       'country': 'Ukraine',
#       'location': 'Kyiv, Ukraine',
#       'company': 'ZOTOV&CO',
#       'occupation': '',
#       'created_on': 1632402362,
#       'url': 'https://www.behance.net/zotovandco',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/a139f21084199295.614c7ded79973.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/a139f21084199295.614c7ded79973.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/a139f21084199295.614c7ded79973.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/a139f21084199295.614c7ded79973.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/a139f21084199295.614c7ded79973.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/a139f21084199295.614c7ded79973.jpg'},
#       'display_name': 'ZOTOV&CO Architecture bureau',
#       'fields': [],
#       'has_default_image': 0,
#       'website': 'http://en.zotov.com.ua/',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/07f45fb232d43610eb5fcf3b3164f0b5/b3ba9b92-5daf-4134-a700-389c6b1c3b0a_rwc_-1x465x1680x170x1680.jpg?h=c6f090b5ba8da2663dbcb64ed5938f7c',
#       'has_premium_access': False,
#       'stats': {'followers': 25,
#        'following': 2,
#        'comments': 0,
#        'appreciations': 1304,
#        'views': 14128}}],
#     'stats': {'views': 11140, 'appreciations': 1016, 'comments': 20},
#     'conceived_on': 1604448000,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1606158060,
#       'site': {'id': 133,
#        'parent_id': 5,
#        'name': 'Архитектурная фотография',
#        'key': 'ArPh',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-photography',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'},
#      {'featured_on': 1642726814,
#       'site': {'id': 295,
#        'parent_id': 0,
#        'name': 'Photoshop',
#        'key': 'photoshop',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/photoshop.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/Photoshop',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/photoshop.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/photoshop@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/photoshop@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/Photoshop'}],
#     'colors': [{'r': 157, 'g': 152, 'b': 148}]},
#    {'id': 131173109,
#     'name': '展厅空间',
#     'published_on': 1636796901,
#     'created_on': 1636796843,
#     'modified_on': 1642698041,
#     'url': 'https://www.behance.net/gallery/131173109/_',
#     'slug': '_',
#     'privacy': 'public',
#     'fields': ['Architecture'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/cc085f131173109.Y3JvcCwyMDU5LDE2MTAsMCw2OTM.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/cc085f131173109.Y3JvcCwyMDU5LDE2MTAsMCw2OTM.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/cc085f131173109.Y3JvcCwyMDU5LDE2MTAsMCw2OTM.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/cc085f131173109.Y3JvcCwyMDU5LDE2MTAsMCw2OTM.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/cc085f131173109.Y3JvcCwyMDU5LDE2MTAsMCw2OTM.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/cc085f131173109.Y3JvcCwyMDU5LDE2MTAsMCw2OTM.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/cc085f131173109.Y3JvcCwyMDU5LDE2MTAsMCw2OTM.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 366502963,
#       'first_name': '梦太初',
#       'last_name': '-',
#       'username': 'a9524500843001',
#       'city': '浙川',
#       'state': '',
#       'country': 'China',
#       'location': '浙川, China',
#       'company': '金该视觉',
#       'occupation': '渲染师，培训导师，V：952450084',
#       'created_on': 1559395159,
#       'url': 'https://www.behance.net/a9524500843001',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/1dd5ca366502963.605ac8d1db1ec.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/1dd5ca366502963.605ac8d1db1ec.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/1dd5ca366502963.605ac8d1db1ec.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/1dd5ca366502963.605ac8d1db1ec.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/1dd5ca366502963.605ac8d1db1ec.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/1dd5ca366502963.605ac8d1db1ec.jpg'},
#       'display_name': '梦太初 -',
#       'fields': ['Architecture', 'CGI', 'Interior Design'],
#       'has_default_image': 0,
#       'website': '',
#       'banner_image_url': '',
#       'has_premium_access': False,
#       'stats': {'followers': 3630,
#        'following': 192,
#        'comments': 35,
#        'appreciations': 5611,
#        'views': 88058}}],
#     'stats': {'views': 2332, 'appreciations': 207, 'comments': 5},
#     'conceived_on': 1636761600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1642698041,
#       'site': {'id': 141,
#        'parent_id': 5,
#        'name': 'Архитектурная визуализация',
#        'key': 'ArcV',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-visualization',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 193, 'g': 185, 'b': 173}]},
#    {'id': 93685993,
#     'name': 'Elsewhere',
#     'published_on': 1584785118,
#     'created_on': 1584052005,
#     'modified_on': 1642654823,
#     'url': 'https://www.behance.net/gallery/93685993/Elsewhere',
#     'slug': 'Elsewhere',
#     'privacy': 'public',
#     'fields': ['Illustration', 'Architecture', 'Digital Art'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/a355f993685993.Y3JvcCwxNDAxLDEwOTUsMCww.png',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/a355f993685993.Y3JvcCwxNDAxLDEwOTUsMCww.png',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/a355f993685993.Y3JvcCwxNDAxLDEwOTUsMCww.png',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/a355f993685993.Y3JvcCwxNDAxLDEwOTUsMCww.png',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/a355f993685993.Y3JvcCwxNDAxLDEwOTUsMCww.png',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/a355f993685993.Y3JvcCwxNDAxLDEwOTUsMCww.png',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/a355f993685993.Y3JvcCwxNDAxLDEwOTUsMCww.png'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 52941,
#       'first_name': 'Maciek',
#       'last_name': 'Blaźniak',
#       'username': 'maciekblazniak',
#       'city': 'Łódź',
#       'state': '',
#       'country': 'Poland',
#       'location': 'Łódź, Poland',
#       'company': 'Studio Ładne Halo',
#       'occupation': 'Pictures maker',
#       'created_on': 1193060590,
#       'url': 'https://www.behance.net/maciekblazniak',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/931c6252941.6040ba77221df.png',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/931c6252941.6040ba77221df.png',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/931c6252941.6040ba77221df.png',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/931c6252941.6040ba77221df.png',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/931c6252941.6040ba77221df.png',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/931c6252941.6040ba77221df.png'},
#       'display_name': 'Maciek Blaźniak',
#       'fields': ['Illustration', 'Graphic Design'],
#       'has_default_image': 0,
#       'website': 'studio.ladne-halo.pl',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/3b1f6fdb38f3760be150e259f3974a00/142161dc-9fd4-4894-b018-3d2deabdf74d_rwc_0x1528x5000x656x5000.png?h=f2f9328759b842daaf3e99c293459a39',
#       'has_premium_access': False,
#       'stats': {'followers': 6127,
#        'following': 497,
#        'comments': 66,
#        'appreciations': 17207,
#        'views': 150302}}],
#     'stats': {'views': 7142, 'appreciations': 1489, 'comments': 61},
#     'conceived_on': 1583971200,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1642654823,
#       'site': {'id': 4,
#        'parent_id': 1,
#        'name': 'Иллюстрация',
#        'key': 'illustration',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/gallery-1.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': 'illustrationserved.com',
#        'url': 'https://www.behance.net/galleries/illustration/illustration',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/illustration.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/illustration@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/illustration@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/illustration'}],
#     'colors': [{'r': 251, 'g': 252, 'b': 253}]},
#    {'id': 134575457,
#     'name': 'HONOR50',
#     'published_on': 1641556015,
#     'created_on': 1641555580,
#     'modified_on': 1642647631,
#     'url': 'https://www.behance.net/gallery/134575457/HONOR50',
#     'slug': 'HONOR50',
#     'privacy': 'public',
#     'fields': ['Photography', 'Architecture'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/e30041134575457.Y3JvcCwyOTI4LDIyOTAsMCw4MDQ.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/e30041134575457.Y3JvcCwyOTI4LDIyOTAsMCw4MDQ.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/e30041134575457.Y3JvcCwyOTI4LDIyOTAsMCw4MDQ.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/e30041134575457.Y3JvcCwyOTI4LDIyOTAsMCw4MDQ.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/e30041134575457.Y3JvcCwyOTI4LDIyOTAsMCw4MDQ.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/e30041134575457.Y3JvcCwyOTI4LDIyOTAsMCw4MDQ.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/e30041134575457.Y3JvcCwyOTI4LDIyOTAsMCw4MDQ.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 91273275,
#       'first_name': 'Thais ',
#       'last_name': 'Varela ',
#       'username': 'azulclacasibla',
#       'city': 'Madrid',
#       'state': '',
#       'country': 'Spain',
#       'location': 'Madrid, Spain',
#       'company': 'THAIS VARELA ',
#       'occupation': 'Freelance Photographer ',
#       'created_on': 1502812750,
#       'url': 'https://www.behance.net/azulclacasibla',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/e640d291273275.6112c54a4e907.png',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/e640d291273275.6112c54a4e907.png',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/e640d291273275.6112c54a4e907.png',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/e640d291273275.6112c54a4e907.png',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/e640d291273275.6112c54a4e907.png',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/e640d291273275.6112c54a4e907.png'},
#       'display_name': 'Thais Varela',
#       'fields': ['Photography', 'Fashion', 'Graphic Design'],
#       'has_default_image': 0,
#       'website': 'www.thaisvarela.com',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/72e3e48f426e346fcfa5bef1b46dc5b1/7cae1efc-1518-4e25-a4bd-30c169a9b3cd_rwc_-1x508x1574x218x1574.png?h=e71d723e98d5a5563158bf30d3dc00b9',
#       'has_premium_access': False,
#       'stats': {'followers': 3121,
#        'following': 308,
#        'comments': 13,
#        'appreciations': 8959,
#        'views': 73967}}],
#     'stats': {'views': 1461, 'appreciations': 172, 'comments': 13},
#     'conceived_on': 1641513600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1642647631,
#       'site': {'id': 133,
#        'parent_id': 5,
#        'name': 'Архитектурная фотография',
#        'key': 'ArPh',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-photography',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 255, 'g': 2, 'b': 0}]},
#    {'id': 135288907,
#     'name': 'Alfa Research Center',
#     'published_on': 1642433932,
#     'created_on': 1642433834,
#     'modified_on': 1642647625,
#     'url': 'https://www.behance.net/gallery/135288907/Alfa-Research-Center',
#     'slug': 'Alfa-Research-Center',
#     'privacy': 'public',
#     'fields': ['Architecture'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/ee3bff135288907.Y3JvcCw3NTU1LDU5MTAsMTY4LDA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/ee3bff135288907.Y3JvcCw3NTU1LDU5MTAsMTY4LDA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/ee3bff135288907.Y3JvcCw3NTU1LDU5MTAsMTY4LDA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/ee3bff135288907.Y3JvcCw3NTU1LDU5MTAsMTY4LDA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/ee3bff135288907.Y3JvcCw3NTU1LDU5MTAsMTY4LDA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/ee3bff135288907.Y3JvcCw3NTU1LDU5MTAsMTY4LDA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/ee3bff135288907.Y3JvcCw3NTU1LDU5MTAsMTY4LDA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 37506381,
#       'first_name': 'IND',
#       'last_name': 'architects',
#       'username': 'indarchitects',
#       'city': 'Moscow',
#       'state': '',
#       'country': 'Russian Federation',
#       'location': 'Moscow, Russian Federation',
#       'company': 'IND architects',
#       'occupation': 'Architecture and design',
#       'created_on': 1466249723,
#       'url': 'https://www.behance.net/indarchitects',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/11485b37506381.6128aff046000.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/11485b37506381.6128aff046000.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/11485b37506381.6128aff046000.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/11485b37506381.6128aff046000.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/11485b37506381.6128aff046000.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/11485b37506381.6128aff046000.jpg'},
#       'display_name': 'IND architects',
#       'fields': ['Architecture', 'Interior Design', 'Graphic Design'],
#       'has_default_image': 0,
#       'website': 'www.indarchitects.ru',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/05abc46dd9a1439ed86f1e5ab5ee8b7f/3a6454d4-b92d-44c7-90a6-36b155197296_rwc_0x612x2016x267x2016.jpg?h=08331525bdcff03bd02ce7491645c979',
#       'has_premium_access': False,
#       'stats': {'followers': 7636,
#        'following': 13,
#        'comments': 6,
#        'appreciations': 17059,
#        'views': 228818}}],
#     'stats': {'views': 1666, 'appreciations': 251, 'comments': 7},
#     'conceived_on': 1642377600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1642647625,
#       'site': {'id': 30,
#        'parent_id': 5,
#        'name': 'Дизайн интерьера',
#        'key': 'interior',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': 'interiordesignserved.com',
#        'url': 'https://www.behance.net/galleries/architecture/interior-design',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 226, 'g': 229, 'b': 223}]},
#    {'id': 133929505,
#     'name': 'CASA SJ de Aguirre Arquitetura',
#     'published_on': 1640626082,
#     'created_on': 1640626002,
#     'modified_on': 1642611640,
#     'url': 'https://www.behance.net/gallery/133929505/CASA-SJ-de-Aguirre-Arquitetura',
#     'slug': 'CASA-SJ-de-Aguirre-Arquitetura',
#     'privacy': 'public',
#     'fields': ['Photography', 'Architecture', '3D Art'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/be98b3133929505.Y3JvcCwyNTU2LDIwMDAsMjIxLDA.png',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/be98b3133929505.Y3JvcCwyNTU2LDIwMDAsMjIxLDA.png',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/be98b3133929505.Y3JvcCwyNTU2LDIwMDAsMjIxLDA.png',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/be98b3133929505.Y3JvcCwyNTU2LDIwMDAsMjIxLDA.png',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/be98b3133929505.Y3JvcCwyNTU2LDIwMDAsMjIxLDA.png',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/be98b3133929505.Y3JvcCwyNTU2LDIwMDAsMjIxLDA.png',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/be98b3133929505.Y3JvcCwyNTU2LDIwMDAsMjIxLDA.png'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 157068889,
#       'first_name': 'Estúdio',
#       'last_name': 'RM2',
#       'username': 'estudiorm2',
#       'city': 'Belo Horizonte',
#       'state': '',
#       'country': 'Brazil',
#       'location': 'Belo Horizonte, Brazil',
#       'company': 'Estúdio RM2',
#       'occupation': 'Architecture visualization',
#       'created_on': 1526519373,
#       'url': 'https://www.behance.net/estudiorm2',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/037ab1157068889.5b65fd29562bf.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/037ab1157068889.5b65fd29562bf.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/037ab1157068889.5b65fd29562bf.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/037ab1157068889.5b65fd29562bf.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/037ab1157068889.5b65fd29562bf.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/037ab1157068889.5b65fd29562bf.jpg'},
# ...
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/528480108105811.Y3JvcCw0NjAyLDM2MDAsODc3LDA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/528480108105811.Y3JvcCw0NjAyLDM2MDAsODc3LDA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/528480108105811.Y3JvcCw0NjAyLDM2MDAsODc3LDA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 79991089,
#       'first_name': 'Walk the',
#       'last_name': 'Room',
#       'username': 'walktheroom',
#       'city': 'Stockholm',
#       'state': '',
#       'country': 'Sweden',
#       'location': 'Stockholm, Sweden',
#       'company': 'Walk the room',
#       'occupation': 'Architecture Design  3d Visualisation ',
#       'created_on': 1497010270,
#       'url': 'https://www.behance.net/walktheroom',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/4da16a79991089.593a9108dc224.png',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/4da16a79991089.593a9108dc224.png',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/4da16a79991089.593a9108dc224.png',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/4da16a79991089.593a9108dc224.png',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/4da16a79991089.593a9108dc224.png',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/4da16a79991089.593a9108dc224.png'},
#       'display_name': 'Walk the Room',
#       'fields': ['Architecture', 'Interior Design', 'Digital Art'],
#       'has_default_image': 0,
#       'website': 'https://www.walktheroom.com/',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/2db81b9df135e6940b48cca1b638e28b/8d71c5a2-eaab-4238-b95f-bbc72a242c5e_rwc_-5x1206x5000x842x5000.jpg?h=378cbcdc020ddb9271797c1f282ab72b',
#       'has_premium_access': False,
#       'stats': {'followers': 10455,
#        'following': 239,
#        'comments': 133,
#        'appreciations': 30807,
#        'views': 378997}}],
#     'stats': {'views': 11888, 'appreciations': 990, 'comments': 27},
#     'conceived_on': 1605744000,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1606521621,
#       'site': {'id': 141,
#        'parent_id': 5,
#        'name': 'Архитектурная визуализация',
#        'key': 'ArcV',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-visualization',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'},
#      {'featured_on': 1641943822,
#       'site': {'id': 295,
#        'parent_id': 0,
#        'name': 'Photoshop',
#        'key': 'photoshop',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/photoshop.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/Photoshop',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/photoshop.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/photoshop@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/photoshop@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/Photoshop'}],
#     'colors': [{'r': 32, 'g': 21, 'b': 17}]},
#    {'id': 133566493,
#     'name': 'RED WALL',
#     'published_on': 1640021427,
#     'created_on': 1640021322,
#     'modified_on': 1641934824,
#     'url': 'https://www.behance.net/gallery/133566493/RED-WALL',
#     'slug': 'RED-WALL',
#     'privacy': 'public',
#     'fields': ['Photography', 'Architecture'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/81911f133566493.Y3JvcCwzMzAyLDI1ODIsMCwxMTY4.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/81911f133566493.Y3JvcCwzMzAyLDI1ODIsMCwxMTY4.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/81911f133566493.Y3JvcCwzMzAyLDI1ODIsMCwxMTY4.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/81911f133566493.Y3JvcCwzMzAyLDI1ODIsMCwxMTY4.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/81911f133566493.Y3JvcCwzMzAyLDI1ODIsMCwxMTY4.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/81911f133566493.Y3JvcCwzMzAyLDI1ODIsMCwxMTY4.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/81911f133566493.Y3JvcCwzMzAyLDI1ODIsMCwxMTY4.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 91273275,
#       'first_name': 'Thais ',
#       'last_name': 'Varela ',
#       'username': 'azulclacasibla',
#       'city': 'Madrid',
#       'state': '',
#       'country': 'Spain',
#       'location': 'Madrid, Spain',
#       'company': 'THAIS VARELA ',
#       'occupation': 'Freelance Photographer ',
#       'created_on': 1502812750,
#       'url': 'https://www.behance.net/azulclacasibla',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/e640d291273275.6112c54a4e907.png',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/e640d291273275.6112c54a4e907.png',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/e640d291273275.6112c54a4e907.png',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/e640d291273275.6112c54a4e907.png',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/e640d291273275.6112c54a4e907.png',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/e640d291273275.6112c54a4e907.png'},
#       'display_name': 'Thais Varela',
#       'fields': ['Photography', 'Fashion', 'Graphic Design'],
#       'has_default_image': 0,
#       'website': 'www.thaisvarela.com',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/72e3e48f426e346fcfa5bef1b46dc5b1/7cae1efc-1518-4e25-a4bd-30c169a9b3cd_rwc_-1x508x1574x218x1574.png?h=e71d723e98d5a5563158bf30d3dc00b9',
#       'has_premium_access': False,
#       'stats': {'followers': 3121,
#        'following': 308,
#        'comments': 13,
#        'appreciations': 8959,
#        'views': 73967}}],
#     'stats': {'views': 2447, 'appreciations': 342, 'comments': 24},
#     'conceived_on': 1639958400,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1641934824,
#       'site': {'id': 133,
#        'parent_id': 5,
#        'name': 'Архитектурная фотография',
#        'key': 'ArPh',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-photography',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 217, 'g': 37, 'b': 4}]},
#    {'id': 133569355,
#     'name': 'GOST',
#     'published_on': 1640257968,
#     'created_on': 1640024494,
#     'modified_on': 1641934821,
#     'url': 'https://www.behance.net/gallery/133569355/GOST',
#     'slug': 'GOST',
#     'privacy': 'public',
#     'fields': ['Architecture', 'Interior Design'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/b9faca133569355.Y3JvcCwyMzMzLDE4MjQsMCw4NTQ.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/b9faca133569355.Y3JvcCwyMzMzLDE4MjQsMCw4NTQ.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/b9faca133569355.Y3JvcCwyMzMzLDE4MjQsMCw4NTQ.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/b9faca133569355.Y3JvcCwyMzMzLDE4MjQsMCw4NTQ.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/b9faca133569355.Y3JvcCwyMzMzLDE4MjQsMCw4NTQ.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/b9faca133569355.Y3JvcCwyMzMzLDE4MjQsMCw4NTQ.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/b9faca133569355.Y3JvcCwyMzMzLDE4MjQsMCw4NTQ.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 325587,
#       'first_name': 'YOD ',
#       'last_name': 'Group',
#       'username': 'yod',
#       'city': 'Kyiv',
#       'state': '',
#       'country': 'Ukraine',
#       'location': 'Kyiv, Ukraine',
#       'company': 'YOD Group',
#       'occupation': '',
#       'created_on': 1297880060,
#       'url': 'https://www.behance.net/yod',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/d6cfdc325587.61cc387f672a2.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/d6cfdc325587.61cc387f672a2.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/d6cfdc325587.61cc387f672a2.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/d6cfdc325587.61cc387f672a2.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/d6cfdc325587.61cc387f672a2.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/d6cfdc325587.61cc387f672a2.jpg'},
#       'display_name': 'YOD Group',
#       'fields': ['Interior Design', 'Architecture', 'Product Design'],
#       'has_default_image': 0,
#       'website': 'http://yoddesign.com.ua/en/',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/9c93da626275b2105cec9209d14c372e/aa8bed25-b381-4b62-a2b2-130a19d4e319_rwc_0x137x1280x141x1280.jpg?h=d8078b44af2cd94ebf5af3b331bd73fb',
#       'has_premium_access': False,
#       'stats': {'followers': 27176,
#        'following': 154,
#        'comments': 95,
#        'appreciations': 73572,
#        'views': 1062129}}],
#     'stats': {'views': 4448, 'appreciations': 574, 'comments': 18},
#     'conceived_on': 1639958400,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1641934821,
#       'site': {'id': 30,
#        'parent_id': 5,
#        'name': 'Дизайн интерьера',
#        'key': 'interior',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': 'interiordesignserved.com',
#        'url': 'https://www.behance.net/galleries/architecture/interior-design',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 89, 'g': 40, 'b': 14}]},
#    {'id': 134764803,
#     'name': 'ON THE ROAD',
#     'published_on': 1641818389,
#     'created_on': 1641818191,
#     'modified_on': 1642778197,
#     'url': 'https://www.behance.net/gallery/134764803/ON-THE-ROAD',
#     'slug': 'ON-THE-ROAD',
#     'privacy': 'public',
#     'fields': ['Photography', 'Architecture'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/3badc1134764803.Y3JvcCwyNzY0LDIxNjEsMCw1NDA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/3badc1134764803.Y3JvcCwyNzY0LDIxNjEsMCw1NDA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/3badc1134764803.Y3JvcCwyNzY0LDIxNjEsMCw1NDA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/3badc1134764803.Y3JvcCwyNzY0LDIxNjEsMCw1NDA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/3badc1134764803.Y3JvcCwyNzY0LDIxNjEsMCw1NDA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/3badc1134764803.Y3JvcCwyNzY0LDIxNjEsMCw1NDA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/3badc1134764803.Y3JvcCwyNzY0LDIxNjEsMCw1NDA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 3114643,
#       'first_name': 'Ludwig',
#       'last_name': 'Favre',
#       'username': 'LUDWIGFAVRE',
#       'city': 'Paris',
#       'state': '',
#       'country': 'France',
#       'location': 'Paris, France',
#       'company': 'PacifiCoast • GEO Awards ',
#       'occupation': 'Artist Photographer ',
#       'created_on': 1374051711,
#       'url': 'https://www.behance.net/LUDWIGFAVRE',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/e4528a3114643.616586239bf19.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/e4528a3114643.616586239bf19.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/e4528a3114643.616586239bf19.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/e4528a3114643.616586239bf19.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/e4528a3114643.616586239bf19.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/e4528a3114643.616586239bf19.jpg'},
#       'display_name': 'Ludwig Favre',
#       'fields': ['Photography', 'Architecture'],
#       'has_default_image': 0,
#       'website': 'http://www.ludwigfavre.com',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/5f88fbf1f847491e40177dc3d336a609/87a179d9-43f5-4c72-b1ad-3fe56d5f86fd_rwc_0x1042x3200x545x3200.jpg?h=8395ac764ff350b83eebc275c6d6fae4',
#       'has_premium_access': False,
#       'stats': {'followers': 30002,
#        'following': 76,
#        'comments': 748,
#        'appreciations': 81716,
#        'views': 880393}}],
#     'stats': {'views': 3711, 'appreciations': 516, 'comments': 68},
#     'conceived_on': 1641772800,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1641933019,
#       'site': {'id': 1,
#        'name': 'Behance.net',
#        'key': 'net',
#        'icon': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/site/favicon.ico',
#        'url': 'http://www.behance.net',
#        'domain': 'www.behance.net',
#        'ribbon': {'image': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/1x/network.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/2x/network@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/592e4f1eea918cb8f23c97873926ed55a97603b1/img/galleries/icons/ribbons/3x/network@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries'}],
#     'colors': [{'r': 0, 'g': 3, 'b': 78}]}]},
#  'suggestedTags': [],
#  'stockImages': [],
#  'stockImagesIsFetching': False,
#  'itemsPerPage': 48,
#  'nextOrdinal': 48,
#  'endCursor': '',
#  'isSafeBrowsing': True,
#  'showMature': False,
#  'metaContent': {'toolCard': None,
#   'schoolCard': None,
#   'csam': {'isCSAMViolation': False,
#    'title': '',
#    'description': '',
#    'reportingOption': '',
#    'helpResource': ''}},
#  'similarImagesSource': None,
#  'typeaheadResults': [],
#  'lastSearchTerm': '',
#  'nextPage': 'https://www.behance.net/search?sort=recommended&time=week&field=architecture&ordinal=48'}

# %%
# name
# first name
# last name
# user name
# country
# views
# appreciations
# comments
# url

# %%
# name
results_json['search']['content']['projects'][0]['name']
# Out:
# 'CITY MUSEUM'

# %%
# first name
results_json['search']['content']['projects'][0]['owners'][0]['first_name']
# Out:
# 'replus'

# %%
# last name
results_json['search']['content']['projects'][0]['owners'][0]['last_name']
# Out:
# 'bureau'

# %%
# user name
results_json['search']['content']['projects'][0]['owners'][0]['username']
# Out:
# 'replusbureau'

# %%
# country
results_json['search']['content']['projects'][0]['owners'][0]['country']
# Out:
# 'Ukraine'

# %%
# views
results_json['search']['content']['projects'][0]['owners'][0]['stats']['views']
# Out:
# 3773

# %%
# appreciations
results_json['search']['content']['projects'][0]['owners'][0]['stats']['appreciations']
# Out:
# 778

# %%
# comments
results_json['search']['content']['projects'][0]['owners'][0]['stats']['comments']
# Out:
# 0

# %%
# url
results_json['search']['content']['projects'][0]['owners'][0]['url']
# Out:
# 'https://www.behance.net/replusbureau'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %% [markdown]
# #### Step 10 - Store Results in Excel
